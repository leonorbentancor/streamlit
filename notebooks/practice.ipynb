# %% [markdown]
# ## Práctica
#
# Puedes utilizar este notebook para analisar el dataset propuesto

# %%
import streamlit as st
import pandas as pd

# %%
from sklearn import datasets
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()
df_california = pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
df_california["MedHouseVal"] = housing.target
df_california
df_california.dtypes
# Out:
# MedInc         float64
# HouseAge       float64
# AveRooms       float64
# AveBedrms      float64
# Population     float64
# AveOccup       float64
# Latitude       float64
# Longitude      float64
# MedHouseVal    float64
# dtype: object

# %%
st.subheader # Con esto se muestra còdigo en el streamlit
st.write
# Out:
# <bound method WriteMixin.write of DeltaGenerator()>

# %%
st.dataframe(df_california.head())
# Out:
# 2025-12-02 21:35:01.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:01.676 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:01.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
###Estilo de Vivienda

# %%
min_age = int(df_california["HouseAge"].min()) # Tengo los datos en float, y slider solo funciona con entero, entonces convierto a entero para utilizar la funcion.
max_age = int(df_california["HouseAge"].max())

# %%
house_age_range = st.sidebar.slider("Rango de Edad Mediana de la Casa", min_value = int(df_california['HouseAge'].min()),max_value = int(df_california['HouseAge'].max()), value = (min_age, max_age) )
# Out:
# 2025-12-02 21:35:59.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:59.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:59.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:59.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:59.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:35:59.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
###Filtro de Vecindario

# %%
active_filtro = st.checkbox("Filtrar por Latitud Mínima")
# Out:
# 2025-12-02 21:36:08.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:08.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:08.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:08.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:08.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:08.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
lat_min = st.sidebar.number_input( "Latitud mínima", min_value=float(df_california["Latitude"].min()),
    max_value=float(df_california["Latitude"].max()), value = float(df_california["Latitude"].min()))
# Out:
# 2025-12-02 21:36:39.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:39.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:39.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:39.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:39.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:39.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:36:39.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df_filtered = df_filtered[df_filtered["Latitude"] >= lat_min]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df_filtered = df_filtered[df_filtered["Latitude"] >= lat_min]
#
# NameError: name 'df_filtered' is not defined

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ###Gráfico de Distribución del Target

# %%
st.subheader("Distribución del Valor Mediano de la Vivienda (MedHouseVal)")

fig, ax = plt.subplots() # Crea el área donde dibujar
ax.hist(df_filtered["MedHouseVal"], bins=30)
ax.set_xlabel("MedHouseVal")
ax.set_ylabel("Frecuencia")
ax.set_title("Histograma del Valor Mediano de Vivienda")

st.pyplot(fig) # Muestra la figura
# Out:
# 2025-12-02 21:37:21.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:37:21.461 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:37:21.462 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 st.subheader("Distribución del Valor Mediano de la Vivienda (MedHouseVal)")
#       3 fig, ax = plt.subplots() # Crea el área donde dibujar
# ----> 4 ax.hist(df_filtered["MedHouseVal"], bins=30)
#       5 ax.set_xlabel("MedHouseVal")
#       6 ax.set_ylabel("Frecuencia")
#
# NameError: name 'df_filtered' is not defined

# %%
###Gráfico de Dispersión (MedInc vs MedHouseVal)

# %%
st.subheader("Relación entre Ingresos y Valor de Vivienda")

fig2, ax2 = plt.subplots()
ax2.scatter(df_filtered["MedInc"], df_filtered["MedHouseVal"], alpha=0.5) # Crea el gráfico de puntos
ax2.set_xlabel("Mediana de Ingresos (MedInc)")
ax2.set_ylabel("Valor Mediano de la Vivienda (MedHouseVal)")
ax2.set_title("Scatter Plot: MedInc vs MedHouseVal")

st.pyplot(fig2)
# Out:
# 2025-12-02 21:37:47.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:37:47.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:37:47.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       1 st.subheader("Relación entre Ingresos y Valor de Vivienda")
#       3 fig2, ax2 = plt.subplots()
# ----> 4 ax2.scatter(df_filtered["MedInc"], df_filtered["MedHouseVal"], alpha=0.5) # Crea el gráfico de puntos
#       5 ax2.set_xlabel("Mediana de Ingresos (MedInc)")
#       6 ax2.set_ylabel("Valor Mediano de la Vivienda (MedHouseVal)")
#
# NameError: name 'df_filtered' is not defined

# %% [markdown]
# ###Mapa Geográfico

# %%
st.subheader("Mapa Geográfico de Viviendas Filtradas")
df_map = df_filtered.rename(columns={"Latitude": "lat", "Longitude": "lon"})
st.map(df_map[["lat", "lon"]])
# Out:
# 2025-12-02 21:33:18.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:33:18.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-02 21:33:18.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 st.subheader("Mapa Geográfico de Viviendas Filtradas")
# ----> 2 df_map = df_filtered.rename(columns={"Latitude": "lat", "Longitude": "lon"})
#       3 st.map(df_map[["lat", "lon"]])
#
# NameError: name 'df_filtered' is not defined
